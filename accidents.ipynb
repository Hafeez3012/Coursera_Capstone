# %%
# Importing the neccessary libraries and packages for our data exploration analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading of the file
df = pd.read_csv('Data-Collisions.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# ...

# %%
# first choosing columns required
required = ['SEVERITYCODE','ADDRTYPE','SEVERITYDESC','COLLISIONTYPE','JUNCTIONTYPE','WEATHER','ROADCOND','LIGHTCOND','SPEEDING','ST_COLDESC','HITPARKEDCAR']

# %%
new_df = df[required]

# %%
new_df.head(3)
# Out:
#    SEVERITYCODE      ADDRTYPE                    SEVERITYDESC COLLISIONTYPE  \
# 0             2  Intersection                Injury Collision        Angles
# 1             1         Block  Property Damage Only Collision     Sideswipe
# 2             1         Block  Property Damage Only Collision    Parked Car
#
#                               JUNCTIONTYPE   WEATHER ROADCOND  \
# 0   At Intersection (intersection related)  Overcast      Wet
# 1  Mid-Block (not related to intersection)   Raining      Wet
# 2  Mid-Block (not related to intersection)  Overcast      Dry
#
#                  LIGHTCOND SPEEDING  \
# 0                 Daylight      NaN
# 1  Dark - Street Lights On      NaN
# 2                 Daylight      NaN
#
#                                           ST_COLDESC HITPARKEDCAR
# 0                                  Entering at angle            N
# 1  From same direction - both going straight - bo...            N
# ...

# %%
new_df.shape
# Out:
# (194673, 11)

# %%
# Total number of null or empty cells in each columns
new_df.isna().sum()
# Out:
# SEVERITYCODE          0
# ADDRTYPE           1926
# SEVERITYDESC          0
# COLLISIONTYPE      4904
# JUNCTIONTYPE       6329
# WEATHER            5081
# ROADCOND           5012
# LIGHTCOND          5170
# SPEEDING         185340
# ST_COLDESC         4904
# HITPARKEDCAR          0
# dtype: int64

# %%
new_df['SPEEDING'].replace(np.nan, 'N', inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
new_df.dropna(inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.countplot(x='SEVERITYCODE', data=new_df)

# %%
sns.countplot(x='SEVERITYCODE', hue='ADDRTYPE', data = new_df)

# %%
sns.countplot(x='SEVERITYCODE', hue='COLLISIONTYPE', data = new_df)

# %%
sns.countplot(x='SEVERITYCODE', hue='ADDRTYPE', data = new_df)

# %%
new_df['COLLISIONTYPE'].hist(bins=20, figsize=(10,5))

# %%
sns.countplot(x='SEVERITYCODE', hue='JUNCTIONTYPE', data = new_df)

# %%
sns.countplot(x='SEVERITYCODE', hue='LIGHTCOND', data = new_df)

# %%
sns.countplot(x='SEVERITYCODE', hue='WEATHER', data = new_df)

# %%
sns.countplot(x='SEVERITYCODE', hue='SPEEDING', data = new_df)

# %%
new_df['HITPARKEDCAR'].value_counts()
# Out:
# N    177205
# Y      5690
# Name: HITPARKEDCAR, dtype: int64

# %%
sns.countplot(x='SEVERITYCODE', hue='HITPARKEDCAR', data = new_df)

# %%
sns.countplot(x='SEVERITYCODE', hue='ROADCOND', data = new_df)
